# %% [raw]
#  <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# The LMR database of Common ERA records includes data in the PAGES2k phases 2 and 3 compilations as well as additional records collected from NCDC.

# %%
# %matplotlib inline

import os
import cPickle
import numpy as np
import pandas as pd
import plotly
import plotly.graph_objs as go

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib.colors import from_levels_and_colors
from mpl_toolkits.basemap import Basemap

figdir = 'Figs/'

proxy_pandas_metafile = 'NCDC_v0.1.0all_Metadata.df.pckl'
proxy_pandas_datafile = 'NCDC_v0.1.0all_Proxies.df.pckl'

proxy_meta = pd.read_pickle(proxy_pandas_metafile)
proxy_data = pd.read_pickle(proxy_pandas_datafile)
lat = proxy_meta['Lat (N)'].values
lon = proxy_meta['Lon (E)'].values
oldest = proxy_meta['Oldest (C.E.)'].values

# %%
plt.figure(figsize=(20,10))
m = Basemap(projection='moll',llcrnrlat=-87,urcrnrlat=81,lon_0=0,\
            llcrnrlon=0,urcrnrlon=360,resolution='c');
# draw parallels and meridians.
parallels = np.arange(-90.,90.,30.)
# Label the meridians and parallels
m.drawparallels(parallels,labels=[False,True,True,False])
# Draw Meridians and Labels
meridians = np.arange(-180.,181.,30.)
m.drawmeridians(meridians)
m.drawmapboundary(fill_color='white')

x,y = m(lon,lat)
sc = plt.scatter(x,y, c=oldest,edgecolors='none',vmin=1000, vmax =2000, cmap='jet', s=20)
cbar = plt.colorbar(sc, shrink = .7)
cbar.set_label('Oldest age in record')
m.drawcoastlines()
plt.title('LMR proxies')
plt.show();

# %% [markdown]
# This figure of the PAGES2k data from Saenger shows more marine records:

# %%
from IPython.display import Image
Image(filename = "pages2kfromsaenger.png")

# %%
# Find annually resolved records spanning between 1700 and 1900. Where are they? How many are there?
#y17 = (proxy_meta['Oldest (C.E.)']<1700).tolist and  (proxy_meta['Youngest (C.E.)']>1900).tolist

pm2 = proxy_meta[(proxy_meta['Oldest (C.E.)']<1800)\
                  & (proxy_meta['Youngest (C.E.)']>1900)\
                  & (proxy_meta['Resolution (yr)']==1)]

lat2 = pm2['Lat (N)'].values
lon2 = pm2['Lon (E)'].values
res2 = pm2['Resolution (yr)'].values
oldest2 = pm2['Oldest (C.E.)'].values

# %% [markdown]
# These are records spanning between 1750 and 1900 with annual resolution. They are mostly from tree rings.

# %%
plt.figure(figsize=(20,10))
m = Basemap(projection='moll',llcrnrlat=-87,urcrnrlat=81,lon_0=0,\
            llcrnrlon=0,urcrnrlon=360,resolution='c');
# draw parallels and meridians.
parallels = np.arange(-90.,90.,30.)
# Label the meridians and parallels
m.drawparallels(parallels,labels=[False,True,True,False])
# Draw Meridians and Labels
meridians = np.arange(-180.,181.,30.)
m.drawmeridians(meridians)
m.drawmapboundary(fill_color='white')

x,y = m(lon2,lat2)
sc = plt.scatter(x,y, c=res2,edgecolors='none',vmin=1, vmax =10, cmap='jet', s=20)
cbar = plt.colorbar(sc, shrink = .7)
cbar.set_label('Sampling interval (years)')
m.drawcoastlines()
plt.title('LMR proxies')
plt.show();

# %%
# Append grid location information to the data metafile

# Define a grid
RES = 4;
lon_g = np.linspace(0,360,num=360/RES +1)
lat_g = np.linspace(-90,90,num=180/RES +1)

# Define a new metadata file that has grid coordinates for this resolution choice
proxy_meta_g4 = proxy_meta;

proxy_meta_g4['lat_ind'] = np.ones(len(proxy_meta_g4['NCDC ID']))*np.nan
proxy_meta_g4['lon_ind'] = np.ones(len(proxy_meta_g4['NCDC ID']))*np.nan

## Determine lat_ind and lon_ind for every record

# List of proxy sites
site_list = list(proxy_data.columns.values)

# Loop over sites
#for site in site_list:
#    site_meta = proxy_meta[proxy_meta['NCDC ID'] == site]
#    lon_s = site_meta['Lon (E)'].iloc[0]
#    lat_s = site_meta['Lat (N)'].iloc[0]
#    proxy_meta_g4.set_value(site,'lat_ind',4)

for index, row in proxy_meta_g4.iterrows():
    lon_s = row['Lon (E)']
    lat_s = row['Lat (N)']
    lat_ind = np.digitize(lat_s,lat_g,right=True)
    lon_ind = np.digitize(lon_s,lon_g,right=True)
    proxy_meta_g4.set_value(index,'lat_ind',lat_ind)
    proxy_meta_g4.set_value(index,'lon_ind',lon_ind)

# %%
##### EOFs of just the normalized data over an interval (no averaging)

# Pick out records that meet some coverage criteria
# For now, I want records with annual resolution with coverage between 1800 and 1900 (2000?)
# Decide later whether to eliminate records that don't span the duration

# Establish some criteria from the meta data for which records are included
crit = (proxy_meta['Oldest (C.E.)']<1800)\
                  & (proxy_meta['Youngest (C.E.)']>1900)\
                  & (proxy_meta['Resolution (yr)']==1);

proxy_datat = proxy_data.transpose()

test = (proxy_data.columns.values)
test = (proxy_data.columns[crit])
test1 = proxy_data[test].loc[1800:2000]
test1
#test1 = pd.DataFrame(test[crit])
#test1

# Want this to give a df of records matching the crit:
#test = proxy_data[pd.DataFrame(crit)]
#test = proxy_data[crit]

# Gives a df of records matching the crit and the year range
#test = proxy_data[pd.DataFrame(np.transpose(crit))].loc[1800:2000]

# Gives a matrix of records matching the crit and the year range
# test = proxy_data[pd.DataFrame(crit)]#.values[1800:2000]

# syntax: df['column name' or dataframe].values[start:end]
# Out:
#            00ITAS03:d18O  00LawD01:d18O  00berm01b:d18O  01cpac01a:d18O  \
# Year C.E.
# 1800.0        -42.639360       -22.2359             NaN             NaN
# 1801.0        -44.077936       -21.9264             NaN             NaN
# 1802.0        -42.677356       -22.7182             NaN             NaN
# 1803.0        -42.380611       -22.0810             NaN             NaN
# 1804.0        -43.023778       -24.1500             NaN             NaN
# 1805.0        -43.710929       -22.2808             NaN             NaN
# 1806.0        -42.447067       -22.1541             NaN             NaN
# 1807.0        -44.814440       -23.3892             NaN             NaN
# 1808.0        -43.922962       -23.4284             NaN             NaN
# 1809.0        -42.845240       -22.6351             NaN             NaN
# 1810.0        -44.475536       -21.9860             NaN             NaN
# 1811.0        -42.640240       -22.6419             NaN             NaN
# 1812.0        -42.990800       -21.7067             NaN             NaN
# 1813.0        -43.778356       -21.7902             NaN             NaN
# 1814.0        -43.225513       -21.9451             NaN             NaN
# 1815.0        -43.710880       -22.3417             NaN             NaN
# 1816.0        -44.878791       -22.8121             NaN             NaN
# 1817.0        -44.312743       -23.3461             NaN             NaN
# 1818.0        -42.033414       -22.8373             NaN             NaN
# 1819.0        -40.897500       -21.9834             NaN             NaN
# 1820.0        -41.843338       -23.3027             NaN             NaN
# 1821.0        -42.885333       -22.2601             NaN             NaN
# 1822.0        -42.643237       -22.9072             NaN             NaN
# 1823.0        -43.658243       -22.8112             NaN             NaN
# 1824.0        -46.075862       -21.7781             NaN             NaN
# 1825.0        -43.340533       -22.2651             NaN             NaN
# 1826.0        -41.192833       -21.9115             NaN             NaN
# 1827.0        -43.286550       -22.0181             NaN             NaN
# 1828.0        -42.811786       -21.8853             NaN             NaN
# 1829.0        -42.953143       -21.0543             NaN             NaN
# ...                  ...            ...             ...             ...
# 1971.0        -44.015718       -22.4258             NaN       -4.724167
# 1972.0        -43.121325       -22.4106             NaN       -5.078333
# 1973.0        -41.483318       -22.7375             NaN       -4.710833
# 1974.0        -44.332500       -21.3997             NaN       -4.828333
# 1975.0        -44.573420       -20.6353             NaN       -4.700833
# 1976.0        -44.048586       -22.8407             NaN       -4.989167
# 1977.0        -44.888174       -21.1882             NaN       -4.956667
# 1978.0        -41.218180       -22.9449             NaN       -4.947500
# 1979.0        -44.131006       -22.5583             NaN       -5.087500
# 1980.0        -47.398850       -22.2687             NaN       -5.121667
# 1981.0        -42.131700       -21.9125             NaN       -5.028333
# 1982.0        -42.863583       -21.7452             NaN       -5.110000
# 1983.0        -43.146725       -21.6982             NaN       -5.019167
# 1984.0        -46.347025       -21.2915             NaN       -4.901667
# 1985.0        -43.376610       -22.5912             NaN       -5.001667
# 1986.0        -45.404955       -23.1174             NaN       -5.250833
# 1987.0        -42.096244       -23.0747             NaN       -5.230000
# 1988.0        -41.747035       -21.2233             NaN       -4.975833
# 1989.0        -42.722523       -21.9105             NaN       -5.027500
# 1990.0        -41.344271       -23.4321             NaN       -5.207500
# 1991.0        -43.089407       -22.2038             NaN       -5.327500
# 1992.0        -43.879209       -22.1638             NaN       -5.236667
# 1993.0        -41.696056       -22.7541             NaN       -5.325000
# 1994.0        -41.105479       -23.1217             NaN       -5.381667
# 1995.0        -42.612373       -22.3251             NaN       -5.182500
# 1996.0        -42.280827       -21.2777             NaN       -5.232500
# 1997.0        -41.797468       -23.1874             NaN       -5.444167
# 1998.0        -40.274033       -22.4601             NaN             NaN
# 1999.0               NaN       -23.8338             NaN             NaN
# 2000.0        -43.639400            NaN             NaN             NaN
#
#            02Dron01:d18O  02aust01a:U/Ca_anom  03Penn01:MFP  03cpac02a:d18O  \
# Year C.E.
# 1800.0               NaN                  NaN           NaN             NaN
# 1801.0            -44.82                  NaN           NaN             NaN
# 1802.0            -46.35                  NaN           NaN             NaN
# 1803.0            -46.42        -4.430000e-09           NaN             NaN
# 1804.0            -44.80                  NaN           NaN             NaN
# 1805.0            -45.22                  NaN           NaN             NaN
# 1806.0            -46.48                  NaN           NaN             NaN
# 1807.0            -45.90                  NaN           NaN             NaN
# 1808.0            -45.37        -1.330000e-08           NaN             NaN
# 1809.0            -46.65                  NaN        80.286             NaN
# 1810.0            -47.14                  NaN           NaN             NaN
# 1811.0            -47.08                  NaN           NaN             NaN
# 1812.0            -46.63                  NaN           NaN             NaN
# 1813.0            -47.15        -1.090000e-08           NaN             NaN
# 1814.0            -46.71                  NaN           NaN             NaN
# 1815.0            -46.75                  NaN           NaN             NaN
# 1816.0            -46.77                  NaN           NaN             NaN
# 1817.0            -45.83                  NaN           NaN             NaN
# 1818.0            -44.96         3.090000e-08           NaN             NaN
# 1819.0            -45.93                  NaN           NaN             NaN
# 1820.0            -46.86                  NaN           NaN             NaN
# 1821.0            -46.48                  NaN           NaN             NaN
# 1822.0            -45.77                  NaN           NaN             NaN
# 1823.0            -45.86        -1.120000e-08           NaN             NaN
# 1824.0            -46.53                  NaN           NaN             NaN
# 1825.0            -46.66                  NaN           NaN             NaN
# 1826.0            -46.12                  NaN           NaN             NaN
# 1827.0            -47.60                  NaN           NaN             NaN
# 1828.0            -47.89        -9.760000e-09           NaN             NaN
# 1829.0            -46.65                  NaN           NaN             NaN
# ...                  ...                  ...           ...             ...
# 1971.0            -43.38                  NaN           NaN             NaN
# 1972.0            -43.95                  NaN           NaN             NaN
# 1973.0            -46.19        -1.130000e-08           NaN             NaN
# 1974.0            -45.55                  NaN           NaN             NaN
# 1975.0            -43.52                  NaN           NaN             NaN
# 1976.0            -43.52                  NaN           NaN             NaN
# 1977.0            -41.02                  NaN           NaN             NaN
# 1978.0            -44.29        -2.170000e-08           NaN             NaN
# 1979.0            -43.78                  NaN           NaN             NaN
# 1980.0            -42.21                  NaN           NaN             NaN
# 1981.0            -45.65                  NaN           NaN             NaN
# 1982.0            -44.65                  NaN           NaN             NaN
# 1983.0            -47.59        -4.130000e-08           NaN             NaN
# 1984.0            -46.09                  NaN        80.419             NaN
# 1985.0            -47.37                  NaN           NaN             NaN
# 1986.0            -50.39                  NaN           NaN             NaN
# 1987.0            -45.94                  NaN           NaN             NaN
# 1988.0            -45.49                  NaN           NaN             NaN
# 1989.0            -46.83                  NaN           NaN             NaN
# 1990.0            -45.91                  NaN           NaN             NaN
# 1991.0            -44.81                  NaN           NaN             NaN
# 1992.0            -45.66                  NaN           NaN             NaN
# 1993.0            -46.59                  NaN           NaN             NaN
# 1994.0            -45.39                  NaN           NaN             NaN
# 1995.0            -41.82                  NaN           NaN             NaN
# 1996.0            -43.58                  NaN           NaN             NaN
# 1997.0            -45.74                  NaN           NaN             NaN
# 1998.0               NaN                  NaN           NaN             NaN
# 1999.0               NaN                  NaN           NaN             NaN
# 2000.0               NaN                  NaN           NaN             NaN
#
#            03cpac03b:d18O  04fiji01a:d13C                ...                  \
# Year C.E.                                                ...
# 1800.0                NaN             NaN                ...
# 1801.0                NaN             NaN                ...
# 1802.0                NaN             NaN                ...
# 1803.0                NaN             NaN                ...
# 1804.0                NaN             NaN                ...
# 1805.0                NaN             NaN                ...
# 1806.0                NaN             NaN                ...
# 1807.0                NaN             NaN                ...
# 1808.0                NaN             NaN                ...
# 1809.0                NaN             NaN                ...
# 1810.0                NaN             NaN                ...
# 1811.0                NaN             NaN                ...
# 1812.0                NaN             NaN                ...
# 1813.0                NaN             NaN                ...
# 1814.0                NaN             NaN                ...
# 1815.0                NaN             NaN                ...
# 1816.0                NaN             NaN                ...
# 1817.0                NaN             NaN                ...
# 1818.0                NaN             NaN                ...
# 1819.0                NaN             NaN                ...
# 1820.0                NaN             NaN                ...
# 1821.0                NaN             NaN                ...
# 1822.0                NaN             NaN                ...
# 1823.0                NaN             NaN                ...
# 1824.0                NaN             NaN                ...
# 1825.0                NaN             NaN                ...
# 1826.0                NaN             NaN                ...
# 1827.0                NaN             NaN                ...
# 1828.0                NaN             NaN                ...
# 1829.0                NaN             NaN                ...
# ...                   ...             ...                ...
# 1971.0                NaN        0.190000                ...
# 1972.0                NaN        0.186667                ...
# 1973.0                NaN        0.316000                ...
# 1974.0                NaN        0.218333                ...
# 1975.0                NaN       -0.046000                ...
# 1976.0                NaN        0.001250                ...
# 1977.0                NaN       -0.026667                ...
# 1978.0                NaN        0.178000                ...
# 1979.0                NaN        0.236667                ...
# 1980.0                NaN             NaN                ...
# 1981.0                NaN        0.326667                ...
# 1982.0                NaN        0.052000                ...
# 1983.0                NaN       -0.048333                ...
# 1984.0                NaN       -0.013333                ...
# 1985.0                NaN       -0.046000                ...
# 1986.0                NaN       -0.028000                ...
# 1987.0                NaN        0.152500                ...
# 1988.0                NaN       -0.366923                ...
# 1989.0                NaN       -0.382222                ...
# 1990.0                NaN       -0.526250                ...
# 1991.0                NaN       -0.481000                ...
# 1992.0                NaN       -0.383636                ...
# 1993.0                NaN       -0.385385                ...
# 1994.0                NaN       -0.304444                ...
# 1995.0                NaN        0.147778                ...
# 1996.0                NaN       -0.198182                ...
# 1997.0                NaN             NaN                ...
# 1998.0                NaN             NaN                ...
# 1999.0                NaN             NaN                ...
# 2000.0                NaN             NaN                ...
#
#            southamerica_chil007B:trsgi_breit  \
# Year C.E.
# 1800.0                                 1.026
# 1801.0                                 1.143
# 1802.0                                 0.926
# 1803.0                                 0.994
# 1804.0                                 1.133
# 1805.0                                 1.063
# 1806.0                                 1.037
# 1807.0                                 0.838
# 1808.0                                 0.942
# 1809.0                                 1.021
# 1810.0                                 1.176
# 1811.0                                 1.305
# 1812.0                                 1.011
# 1813.0                                 0.922
# 1814.0                                 0.761
# 1815.0                                 1.295
# 1816.0                                 0.891
# 1817.0                                 0.744
# 1818.0                                 0.784
# 1819.0                                 0.685
# 1820.0                                 0.872
# 1821.0                                 0.778
# 1822.0                                 1.001
# 1823.0                                 1.047
# 1824.0                                 1.015
# 1825.0                                 1.021
# 1826.0                                 1.089
# 1827.0                                 1.426
# 1828.0                                 1.157
# 1829.0                                 1.072
# ...                                      ...
# 1971.0                                 1.054
# 1972.0                                 1.093
# 1973.0                                 1.410
# 1974.0                                 1.327
# 1975.0                                 1.325
# 1976.0                                   NaN
# 1977.0                                   NaN
# 1978.0                                   NaN
# 1979.0                                   NaN
# 1980.0                                   NaN
# 1981.0                                   NaN
# 1982.0                                   NaN
# 1983.0                                   NaN
# 1984.0                                   NaN
# 1985.0                                   NaN
# 1986.0                                   NaN
# 1987.0                                   NaN
# 1988.0                                   NaN
# 1989.0                                   NaN
# 1990.0                                   NaN
# 1991.0                                   NaN
# 1992.0                                   NaN
# 1993.0                                   NaN
# 1994.0                                   NaN
# 1995.0                                   NaN
# 1996.0                                   NaN
# 1997.0                                   NaN
# 1998.0                                   NaN
# 1999.0                                   NaN
# 2000.0                                   NaN
#
#            southamerica_chil008B:trsgi_breit  \
# Year C.E.
# 1800.0                                 1.155
# 1801.0                                 1.000
# 1802.0                                 1.054
# 1803.0                                 1.144
# 1804.0                                 1.130
# 1805.0                                 1.063
# 1806.0                                 0.997
# 1807.0                                 1.006
# 1808.0                                 1.153
# 1809.0                                 1.134
# 1810.0                                 1.053
# 1811.0                                 0.943
# 1812.0                                 1.040
# 1813.0                                 0.889
# 1814.0                                 1.090
# 1815.0                                 1.149
# 1816.0                                 1.265
# 1817.0                                 1.211
# 1818.0                                 0.937
# 1819.0                                 0.858
# 1820.0                                 1.099
# 1821.0                                 0.967
# 1822.0                                 1.212
# 1823.0                                 1.240
# 1824.0                                 1.326
# 1825.0                                 1.361
# 1826.0                                 1.308
# 1827.0                                 1.234
# 1828.0                                 1.238
# 1829.0                                 1.252
# ...                                      ...
# 1971.0                                 0.962
# 1972.0                                 0.788
# 1973.0                                 0.638
# 1974.0                                 0.800
# 1975.0                                 0.968
# 1976.0                                   NaN
# 1977.0                                   NaN
# 1978.0                                   NaN
# 1979.0                                   NaN
# 1980.0                                   NaN
# 1981.0                                   NaN
# 1982.0                                   NaN
# 1983.0                                   NaN
# 1984.0                                   NaN
# 1985.0                                   NaN
# 1986.0                                   NaN
# 1987.0                                   NaN
# 1988.0                                   NaN
# 1989.0                                   NaN
# 1990.0                                   NaN
# 1991.0                                   NaN
# 1992.0                                   NaN
# 1993.0                                   NaN
# 1994.0                                   NaN
# 1995.0                                   NaN
# 1996.0                                   NaN
# 1997.0                                   NaN
# 1998.0                                   NaN
# 1999.0                                   NaN
# 2000.0                                   NaN
#
#            southamerica_chil009B:trsgi_breit  \
# Year C.E.
# 1800.0                                 1.131
# 1801.0                                 0.991
# 1802.0                                 0.933
# 1803.0                                 0.732
# 1804.0                                 1.038
# 1805.0                                 1.004
# 1806.0                                 1.126
# 1807.0                                 1.125
# 1808.0                                 1.105
# 1809.0                                 1.247
# 1810.0                                 0.980
# 1811.0                                 1.044
# 1812.0                                 0.963
# 1813.0                                 0.943
# 1814.0                                 1.166
# 1815.0                                 1.339
# 1816.0                                 1.104
# 1817.0                                 0.851
# 1818.0                                 0.764
# 1819.0                                 0.845
# 1820.0                                 0.984
# 1821.0                                 0.951
# 1822.0                                 1.054
# 1823.0                                 0.985
# 1824.0                                 1.150
# 1825.0                                 1.160
# 1826.0                                 1.062
# 1827.0                                 0.942
# 1828.0                                 0.955
# 1829.0                                 0.966
# ...                                      ...
# 1971.0                                 1.738
# 1972.0                                 1.556
# 1973.0                                 1.563
# 1974.0                                 1.474
# 1975.0                                 1.250
# 1976.0                                   NaN
# 1977.0                                   NaN
# 1978.0                                   NaN
# 1979.0                                   NaN
# 1980.0                                   NaN
# 1981.0                                   NaN
# 1982.0                                   NaN
# 1983.0                                   NaN
# 1984.0                                   NaN
# 1985.0                                   NaN
# 1986.0                                   NaN
# 1987.0                                   NaN
# 1988.0                                   NaN
# 1989.0                                   NaN
# 1990.0                                   NaN
# 1991.0                                   NaN
# 1992.0                                   NaN
# 1993.0                                   NaN
# 1994.0                                   NaN
# 1995.0                                   NaN
# 1996.0                                   NaN
# 1997.0                                   NaN
# 1998.0                                   NaN
# 1999.0                                   NaN
# 2000.0                                   NaN
#
#            southamerica_chil010B:trsgi_breit  \
# Year C.E.
# 1800.0                                   NaN
# 1801.0                                   NaN
# 1802.0                                   NaN
# 1803.0                                   NaN
# 1804.0                                   NaN
# 1805.0                                   NaN
# 1806.0                                   NaN
# 1807.0                                 0.947
# 1808.0                                 1.076
# 1809.0                                 1.261
# 1810.0                                 0.950
# 1811.0                                 0.998
# 1812.0                                 0.878
# 1813.0                                 0.850
# 1814.0                                 0.868
# 1815.0                                 1.022
# 1816.0                                 0.996
# 1817.0                                 0.991
# 1818.0                                 1.088
# 1819.0                                 0.923
# 1820.0                                 0.841
# 1821.0                                 1.046
# 1822.0                                 0.987
# 1823.0                                 1.051
# 1824.0                                 1.175
# 1825.0                                 0.913
# 1826.0                                 0.832
# 1827.0                                 0.969
# 1828.0                                 0.903
# 1829.0                                 1.081
# ...                                      ...
# 1971.0                                 1.285
# 1972.0                                 0.853
# 1973.0                                 0.747
# 1974.0                                 0.987
# 1975.0                                 1.186
# 1976.0                                   NaN
# 1977.0                                   NaN
# 1978.0                                   NaN
# 1979.0                                   NaN
# 1980.0                                   NaN
# 1981.0                                   NaN
# 1982.0                                   NaN
# 1983.0                                   NaN
# 1984.0                                   NaN
# 1985.0                                   NaN
# 1986.0                                   NaN
# 1987.0                                   NaN
# 1988.0                                   NaN
# 1989.0                                   NaN
# 1990.0                                   NaN
# 1991.0                                   NaN
# 1992.0                                   NaN
# 1993.0                                   NaN
# 1994.0                                   NaN
# 1995.0                                   NaN
# 1996.0                                   NaN
# 1997.0                                   NaN
# 1998.0                                   NaN
# 1999.0                                   NaN
# 2000.0                                   NaN
#
#            southamerica_chil011B:trsgi_breit  \
# Year C.E.
# 1800.0                                 1.045
# 1801.0                                 1.112
# 1802.0                                 1.275
# 1803.0                                 1.132
# 1804.0                                 1.108
# 1805.0                                 1.059
# 1806.0                                 0.896
# 1807.0                                 0.710
# 1808.0                                 0.819
# 1809.0                                 1.190
# 1810.0                                 1.247
# 1811.0                                 1.026
# 1812.0                                 0.995
# 1813.0                                 0.996
# 1814.0                                 1.021
# 1815.0                                 1.176
# 1816.0                                 1.031
# 1817.0                                 1.091
# 1818.0                                 1.053
# 1819.0                                 0.773
# 1820.0                                 1.020
# 1821.0                                 1.106
# 1822.0                                 1.221
# 1823.0                                 1.257
# 1824.0                                 1.155
# 1825.0                                 1.480
# 1826.0                                 1.024
# 1827.0                                 0.999
# 1828.0                                 0.812
# 1829.0                                 1.045
# ...                                      ...
# 1971.0                                 1.381
# 1972.0                                 0.967
# 1973.0                                 0.961
# 1974.0                                 0.796
# 1975.0                                 0.926
# 1976.0                                   NaN
# 1977.0                                   NaN
# 1978.0                                   NaN
# 1979.0                                   NaN
# 1980.0                                   NaN
# 1981.0                                   NaN
# 1982.0                                   NaN
# 1983.0                                   NaN
# 1984.0                                   NaN
# 1985.0                                   NaN
# 1986.0                                   NaN
# 1987.0                                   NaN
# 1988.0                                   NaN
# 1989.0                                   NaN
# 1990.0                                   NaN
# 1991.0                                   NaN
# 1992.0                                   NaN
# 1993.0                                   NaN
# 1994.0                                   NaN
# 1995.0                                   NaN
# 1996.0                                   NaN
# 1997.0                                   NaN
# 1998.0                                   NaN
# 1999.0                                   NaN
# 2000.0                                   NaN
#
#            southamerica_chil012B:trsgi_breit  \
# Year C.E.
# 1800.0                                 1.288
# 1801.0                                 1.105
# 1802.0                                 1.068
# 1803.0                                 0.875
# 1804.0                                 1.007
# 1805.0                                 1.022
# 1806.0                                 1.192
# 1807.0                                 1.126
# 1808.0                                 1.109
# 1809.0                                 1.163
# 1810.0                                 0.933
# 1811.0                                 0.852
# 1812.0                                 0.850
# 1813.0                                 0.786
# 1814.0                                 0.979
# 1815.0                                 0.952
# 1816.0                                 1.107
# 1817.0                                 0.950
# 1818.0                                 0.678
# 1819.0                                 0.842
# 1820.0                                 0.849
# 1821.0                                 0.772
# 1822.0                                 0.915
# 1823.0                                 0.916
# 1824.0                                 1.029
# 1825.0                                 1.240
# 1826.0                                 1.022
# 1827.0                                 1.081
# 1828.0                                 1.232
# 1829.0                                 1.227
# ...                                      ...
# 1971.0                                 0.944
# 1972.0                                 0.733
# 1973.0                                 0.761
# 1974.0                                 0.839
# 1975.0                                 0.884
# 1976.0                                   NaN
# 1977.0                                   NaN
# 1978.0                                   NaN
# 1979.0                                   NaN
# 1980.0                                   NaN
# 1981.0                                   NaN
# 1982.0                                   NaN
# 1983.0                                   NaN
# 1984.0                                   NaN
# 1985.0                                   NaN
# 1986.0                                   NaN
# 1987.0                                   NaN
# 1988.0                                   NaN
# 1989.0                                   NaN
# 1990.0                                   NaN
# 1991.0                                   NaN
# 1992.0                                   NaN
# 1993.0                                   NaN
# 1994.0                                   NaN
# 1995.0                                   NaN
# 1996.0                                   NaN
# 1997.0                                   NaN
# 1998.0                                   NaN
# 1999.0                                   NaN
# 2000.0                                   NaN
#
#            southamerica_chil013B:trsgi_breit  \
# Year C.E.
# 1800.0                                 1.049
# 1801.0                                 1.008
# 1802.0                                 0.843
# 1803.0                                 0.942
# 1804.0                                 1.026
# 1805.0                                 1.057
# 1806.0                                 0.786
# 1807.0                                 0.727
# 1808.0                                 0.788
# 1809.0                                 0.860
# 1810.0                                 1.112
# 1811.0                                 1.082
# 1812.0                                 1.205
# 1813.0                                 0.877
# 1814.0                                 0.723
# 1815.0                                 1.320
# 1816.0                                 0.953
# 1817.0                                 0.931
# 1818.0                                 0.910
# 1819.0                                 0.810
# 1820.0                                 0.803
# 1821.0                                 0.867
# 1822.0                                 0.932
# 1823.0                                 1.180
# 1824.0                                 1.032
# 1825.0                                 0.805
# 1826.0                                 0.640
# 1827.0                                 0.784
# 1828.0                                 0.632
# 1829.0                                 0.548
# ...                                      ...
# 1971.0                                 0.996
# 1972.0                                 0.817
# 1973.0                                 1.299
# 1974.0                                 1.159
# 1975.0                                 1.133
# 1976.0                                   NaN
# 1977.0                                   NaN
# 1978.0                                   NaN
# 1979.0                                   NaN
# 1980.0                                   NaN
# 1981.0                                   NaN
# 1982.0                                   NaN
# 1983.0                                   NaN
# 1984.0                                   NaN
# 1985.0                                   NaN
# 1986.0                                   NaN
# 1987.0                                   NaN
# 1988.0                                   NaN
# 1989.0                                   NaN
# 1990.0                                   NaN
# 1991.0                                   NaN
# 1992.0                                   NaN
# 1993.0                                   NaN
# 1994.0                                   NaN
# 1995.0                                   NaN
# 1996.0                                   NaN
# 1997.0                                   NaN
# 1998.0                                   NaN
# 1999.0                                   NaN
# 2000.0                                   NaN
#
#            southamerica_chil015B:trsgi_breit  \
# Year C.E.
# 1800.0                                 1.128
# 1801.0                                 0.715
# 1802.0                                 0.952
# 1803.0                                 0.845
# 1804.0                                 1.034
# 1805.0                                 1.123
# 1806.0                                 1.411
# 1807.0                                 1.084
# 1808.0                                 1.136
# 1809.0                                 1.273
# 1810.0                                 1.126
# 1811.0                                 0.998
# 1812.0                                 0.995
# 1813.0                                 0.907
# 1814.0                                 1.074
# 1815.0                                 0.834
# 1816.0                                 0.699
# 1817.0                                 0.934
# 1818.0                                 0.577
# 1819.0                                 0.328
# 1820.0                                 0.692
# 1821.0                                 0.600
# 1822.0                                 0.760
# 1823.0                                 0.644
# 1824.0                                 0.477
# 1825.0                                 0.817
# 1826.0                                 0.669
# 1827.0                                 0.654
# 1828.0                                 0.775
# 1829.0                                 1.146
# ...                                      ...
# 1971.0                                 1.376
# 1972.0                                 1.206
# 1973.0                                 1.169
# 1974.0                                 1.249
# 1975.0                                 1.108
# 1976.0                                 1.247
# 1977.0                                 1.227
# 1978.0                                 0.641
# 1979.0                                 0.800
# 1980.0                                 0.740
# 1981.0                                 1.180
# 1982.0                                 1.100
# 1983.0                                 1.245
# 1984.0                                 0.998
# 1985.0                                 0.961
# 1986.0                                 1.376
# 1987.0                                 0.546
# 1988.0                                   NaN
# 1989.0                                   NaN
# 1990.0                                   NaN
# 1991.0                                   NaN
# 1992.0                                   NaN
# 1993.0                                   NaN
# 1994.0                                   NaN
# 1995.0                                   NaN
# 1996.0                                   NaN
# 1997.0                                   NaN
# 1998.0                                   NaN
# 1999.0                                   NaN
# 2000.0                                   NaN
#
#            southamerica_chil016B:trsgi_breit  \
# Year C.E.
# 1800.0                                 1.422
# 1801.0                                 1.300
# 1802.0                                 1.205
# 1803.0                                 1.072
# 1804.0                                 0.989
# 1805.0                                 1.138
# 1806.0                                 1.350
# 1807.0                                 0.865
# 1808.0                                 1.148
# 1809.0                                 1.160
# 1810.0                                 1.211
# 1811.0                                 0.951
# 1812.0                                 1.251
# 1813.0                                 1.166
# 1814.0                                 0.945
# 1815.0                                 0.807
# 1816.0                                 0.644
# 1817.0                                 0.645
# 1818.0                                 0.409
# 1819.0                                 0.182
# 1820.0                                 0.343
# 1821.0                                 0.486
# 1822.0                                 0.347
# 1823.0                                 0.343
# 1824.0                                 0.195
# 1825.0                                 0.434
# 1826.0                                 0.986
# 1827.0                                 0.955
# 1828.0                                 0.805
# 1829.0                                 1.011
# ...                                      ...
# 1971.0                                 0.728
# 1972.0                                 0.734
# 1973.0                                 0.976
# 1974.0                                 1.034
# 1975.0                                 0.747
# 1976.0                                 0.676
# 1977.0                                 0.617
# 1978.0                                 0.617
# 1979.0                                 0.716
# 1980.0                                 0.806
# 1981.0                                 0.881
# 1982.0                                 0.960
# 1983.0                                 1.195
# 1984.0                                 1.010
# 1985.0                                 0.970
# 1986.0                                 1.001
# 1987.0                                   NaN
# 1988.0                                   NaN
# 1989.0                                   NaN
# 1990.0                                   NaN
# 1991.0                                   NaN
# 1992.0                                   NaN
# 1993.0                                   NaN
# 1994.0                                   NaN
# 1995.0                                   NaN
# 1996.0                                   NaN
# 1997.0                                   NaN
# 1998.0                                   NaN
# 1999.0                                   NaN
# 2000.0                                   NaN
#
#            southamerica_chil018B:trsgi_breit
# Year C.E.
# 1800.0                                 1.107
# 1801.0                                 1.241
# 1802.0                                 1.106
# 1803.0                                 1.320
# 1804.0                                 1.174
# 1805.0                                 1.308
# 1806.0                                 1.259
# 1807.0                                 1.188
# 1808.0                                 0.949
# 1809.0                                 1.076
# 1810.0                                 1.303
# 1811.0                                 1.398
# 1812.0                                 1.287
# 1813.0                                 1.263
# 1814.0                                 1.244
# 1815.0                                 1.161
# 1816.0                                 0.795
# 1817.0                                 0.668
# 1818.0                                 1.019
# 1819.0                                 0.716
# 1820.0                                 0.430
# 1821.0                                 0.500
# 1822.0                                 0.631
# 1823.0                                 0.635
# 1824.0                                 0.730
# 1825.0                                 0.551
# 1826.0                                 0.739
# 1827.0                                 0.790
# 1828.0                                 0.749
# 1829.0                                 0.948
# ...                                      ...
# 1971.0                                 1.094
# 1972.0                                 1.007
# 1973.0                                 1.117
# 1974.0                                 1.119
# 1975.0                                 1.122
# 1976.0                                 0.940
# 1977.0                                 1.038
# 1978.0                                 1.134
# 1979.0                                 0.574
# 1980.0                                 0.558
# 1981.0                                 0.758
# 1982.0                                 0.768
# 1983.0                                 0.864
# 1984.0                                 1.013
# 1985.0                                 1.079
# 1986.0                                 0.796
# 1987.0                                 1.091
# 1988.0                                   NaN
# 1989.0                                   NaN
# 1990.0                                   NaN
# 1991.0                                   NaN
# 1992.0                                   NaN
# 1993.0                                   NaN
# 1994.0                                   NaN
# 1995.0                                   NaN
# 1996.0                                   NaN
# 1997.0                                   NaN
# 1998.0                                   NaN
# 1999.0                                   NaN
# 2000.0                                   NaN
#
# [201 rows x 2019 columns]

# %%
## Pick out records that meet some coverage criteria
# For now, I want records with annual resolution with coverage between 1800 and 1900 (2000?)
# Decide later whether to eliminate records that don't span the duration

# Establish some criteria from the meta data for which records are included
crit = [(proxy_meta['Oldest (C.E.)']<1800)\
                  & (proxy_meta['Youngest (C.E.)']>1900)\
                  & (proxy_meta['Resolution (yr)']==1)];

# Make a subset dataframe of the records to loop over when computing averages

# initialize gridded average field

G = np.nan*np.ones(len(lat_g)-1,len(lon_g)-1)

# Loop over grid lat
# Loop over grid lon


# Normalize records
# Average within the grid
# SVD of gridded data

# %%
test

#pm22 = proxy_meta.iloc[pd.DataFrame(np.transpose(test))]
#proxy_datat = proxy_data.transpose()
#m = pd2.values

#pd2 = proxy_datat.iloc[pd.DataFrame(test)]
proxy_data[test]

# %%
# What does the SV spectrum of those (normalized!) records look like?
test = [(proxy_meta['Oldest (C.E.)']<1800)\
                  & (proxy_meta['Youngest (C.E.)']>1900)\
                  & (proxy_meta['Resolution (yr)']==1)];


#pm22 = proxy_meta.iloc[pd.DataFrame(np.transpose(test))]
#proxy_datat = proxy_data.transpose()
#m = pd2.values

#pd2 = proxy_datat.iloc[pd.DataFrame(test)]
#pd2 = proxy_datat[test]
#proxy_data[test].values[1800:2000]

# df['column name'].values[start:end]

# %%
# What about for different (smoothed?) box averaging?
# What about for different regions?

# %%
whos
# Out:
# Variable                 Type              Data/Info
# ----------------------------------------------------
# Basemap                  type              <class 'mpl_toolkits.basemap.Basemap'>
# RES                      int               4
# ans                      ndarray           : 1 elems, type `int64`, 8 bytes
# cPickle                  module            <module 'cPickle' from '/<...>/lib-dynload/cPickle.so'>
# cbar                     Colorbar          <matplotlib.colorbar.Colo<...>ar object at 0x11957e350>
# colors                   module            <module 'matplotlib.color<...>s/matplotlib/colors.pyc'>
# crit                     Series            0       False\n1       Fa<...>008     True\ndtype: bool
# figdir                   str               Figs/
# from_levels_and_colors   function          <function from_levels_and_colors at 0x10e7e2488>
# go                       module            <module 'plotly.graph_obj<...>graph_objs/__init__.pyc'>
# index                    str               southamerica_chil018B:trsgi_breit
# lat                      ndarray           3009: 3009 elems, type `float64`, 24072 bytes
# lat17                    ndarray           2079: 2079 elems, type `float64`, 16632 bytes
# lat2                     ndarray           2019: 2019 elems, type `float64`, 16152 bytes
# lat_g                    ndarray           46: 46 elems, type `float64`, 368 bytes
# lat_ind                  ndarray           : 1 elems, type `int64`, 8 bytes
# lat_s                    float             nan
# lon                      ndarray           3009: 3009 elems, type `float64`, 24072 bytes
# lon17                    ndarray           2079: 2079 elems, type `float64`, 16632 bytes
# lon2                     ndarray           2019: 2019 elems, type `float64`, 16152 bytes
# lon_g                    ndarray           91: 91 elems, type `float64`, 728 bytes
# lon_ind                  ndarray           : 1 elems, type `int64`, 8 bytes
# lon_s                    float             nan
# m                        ndarray           3009x25224: 75899016 elems, type `float64`, 607192128 bytes (579 Mb)
# matplotlib               module            <module 'matplotlib' from<...>matplotlib/__init__.pyc'>
# meridians                ndarray           13: 13 elems, type `float64`, 104 bytes
# np                       module            <module 'numpy' from '/Us<...>ages/numpy/__init__.pyc'>
# oldest                   ndarray           3009: 3009 elems, type `int64`, 24072 bytes
# oldest17                 ndarray           2079: 2079 elems, type `int64`, 16632 bytes
# oldest2                  ndarray           2019: 2019 elems, type `int64`, 16152 bytes
# os                       module            <module 'os' from '/Appli<...>ts/lib/python2.7/os.pyc'>
# pandas                   module            <module 'pandas' from '/U<...>ges/pandas/__init__.pyc'>
# parallels                ndarray           6: 6 elems, type `float64`, 48 bytes
# pd                       module            <module 'pandas' from '/U<...>ges/pandas/__init__.pyc'>
# pd2                      DataFrame         Year C.E.                <...>009 rows x 25224 columns]
# plotly                   module            <module 'plotly' from '/U<...>ges/plotly/__init__.pyc'>
# plt                      module            <module 'matplotlib.pyplo<...>s/matplotlib/pyplot.pyc'>
# pm17                     DataFrame                                  <...>n[2079 rows x 16 columns]
# pm2                      DataFrame                                  <...>n[2019 rows x 16 columns]
# pm22                     DataFrame                    NCDC ID       <...>, 10, 11, 12]     [LMR]
# proxy_data               DataFrame                    00Epic01:delD <...>5224 rows x 3009 columns]
# proxy_datat              DataFrame         Year C.E.                <...>009 rows x 25224 columns]
# proxy_meta               DataFrame                                  <...>n[3009 rows x 16 columns]
# proxy_meta_g4            DataFrame                                  <...>n[6018 rows x 18 columns]
# proxy_pandas_datafile    str               NCDC_v0.1.0all_Proxies.df.pckl
# proxy_pandas_metafile    str               NCDC_v0.1.0all_Metadata.df.pckl
# res17                    ndarray           2079: 2079 elems, type `int64`, 16632 bytes
# res2                     ndarray           2019: 2019 elems, type `int64`, 16152 bytes
# row                      Series            NCDC ID                  <...>rsgi_breit, dtype: object
# sc                       PathCollection    <matplotlib.collections.P<...>on object at 0x116a35e50>
# site                     str               southamerica_chil018B:trsgi_breit
# site_list                list              n=3009
# site_meta                DataFrame                                  <...>eits]      NaN      NaN
# t                        DataFrame                    00Epic01:delD <...>5224 rows x 3009 columns]
# test                     Index             Index([u'00ITAS03:d18O', <...>pe='object', length=2019)
# test1                    DataFrame                           0\n0   <...>\n[3009 rows x 1 columns]
# x                        ndarray           2019: 2019 elems, type `float64`, 16152 bytes
# y                        ndarray           2019: 2019 elems, type `float64`, 16152 bytes
